# %%
import sys
sys.path.append(
    "/Users/tarik.setia/tetrascience/ts-lib-protocol-script/tools/schema_validator")

import jsonref
from copy import deepcopy
from ids_node import Node

with open("schema.json", 'r') as f:
    schema = jsonref.load(f)
    schema = deepcopy(schema)

# %%
# Out:
# {'$schema': 'http://json-schema.org/draft-07/schema#',
#  '$id': 'http://ids.tetrascience.com/common/lcuv-empower/v7.0.0/schema.json',
#  'type': 'object',
#  'required': ['@idsNamespace',
#   '@idsType',
#   'injection',
#   'user',
#   'system',
#   'database',
#   'project',
#   'sample',
#   'method',
#   'results'],
#  'additionalProperties': False,
#  'definitions': {'nullable_string': {'type': ['string', 'null']},
#   'nullable_number': {'type': ['number', 'null']},
#   'nullable_integer': {'type': ['integer', 'null']},
#   'nullable_boolean': {'type': ['boolean', 'null']},
#   'custom_fields': {'type': 'array',
#    'items': {'type': 'object',
#     'additionalProperties': False,
#     'properties': {'key': {'type': ['string', 'null']},
#      'value': {'type': ['string', 'null']},
#      'value_data_type': {'type': 'string',
#       'enum': ['string', 'number', 'boolean']},
#      'string_value': {'type': ['string', 'null']},
# ...
